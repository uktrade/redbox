# %%
# %load_ext dotenv
# %dotenv -o .env.docker

# %%
import json
import boto3

bedrock = boto3.client(
    service_name='bedrock-runtime',
    region_name='eu-west-2'
)

body = {
    "messages": [
        {
            "role": "user",
            "content": "Your prompt here"
        }
    ],
    "max_tokens": 1000,
    "anthropic_version": "bedrock-2023-05-31"
}

response = bedrock.invoke_model(
    modelId='anthropic.claude-3-sonnet-20240229-v1:0',
    body=json.dumps(body)
)

# Parse the response
response_body = json.loads(response['body'].read())

# %%
response_body
# Out:
# {'id': 'msg_bdrk_01MDWT6Tu7xcb5bRc1qhNHgt',
#  'type': 'message',
#  'role': 'assistant',
#  'model': 'claude-3-sonnet-20240229',
#  'content': [{'type': 'text',
#    'text': "I'm Claude, an AI assistant created by Anthropic. I don't actually have prompts or tasks to complete on my own. I'm here to have a friendly dialogue and try my best to be helpful with any questions or requests you may have!"}],
#  'stop_reason': 'end_turn',
#  'stop_sequence': None,
#  'usage': {'input_tokens': 10, 'output_tokens': 55}}

# %% [markdown]
# Using Claude

# %%
from redbox.models.settings import ChatLLMBackend
from redbox.chains.components import get_chat_llm
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser

chat = get_chat_llm(ChatLLMBackend(name="anthropic.claude-3-sonnet-20240229-v1:0", provider="bedrock"))
template = PromptTemplate(template='Tell me a joke about {topic}', 
                            input_variables=['topic'])

chain = template | chat | StrOutputParser()

chain.invoke({'topic': 'Banana'})
# Out:
# "Here's a funny banana joke for you:\n\nWhy did the banana go to the doctor? Because it wasn't peeling well!"
